# %% [markdown]
# # TP6

# %% [markdown]
#  Realizar algunas consultas CRUD hacia Neo4J desde un entorno Python

# %%
from py2neo import Graph,Node,Relationship
authenticate("localhost:7474", "neo4j", "mauri")
graph = Graph()

# %%
alejandra=Node("persona", name="Alejandra", apellido="Obando")
claudia=Node("persona", name="Claudia", apellido="Obando")
macarena=Node("persona", name="Macarena", apellido="Zabala")
boris=Node("persona", name="Boris", apellido="Zabala")
diego=Node("persona", name="Diego", apellido="Caro")
francisco=Node("persona", name="Francisco", apellido="Fernandez")
mauricio = Node("persona", name="Mauricio", apellido="Romero")
javier = Node("persona", name="Javier", apellido="Romero")
jorge=Node("persona", name="Jorge", apellido="Romero")
patricia=Node("persona", name="Patricia", apellido="Navarro")
andres=Node("persona", name="Andres", apellido="Gutierrez")
natalia=Node("persona", name="Natalia", apellido="Gutierrez")
pamela=Node("persona", name="Pamela", apellido="Perez")
roberto=Node("persona", name="Roberto", apellido="Perez")
constanza=Node("persona", name="Constanza", apellido="Alvarez")
danae=Node("persona", name="Danae", apellido="Gutierrez")
tammy=Node("mascota", name="Tammy",edad=7)
olivia=Node("mascota", name="Olivia",edad=3)
pascuala=Node("mascota", name="Pascuala", edad=1)
linda=Node("mascota", name="Linda", edad=15)
maxima=Node("mascota", name="Maxima", edad=5)
andronico=Node("mascota", name="Andronico", edad=5)
kitty=Node("mascota", name="Kitty",edad=15)
garfield=Node("mascota", name="Garfield", edad=10)
tom=Node("mascota", name="Tom", edad=10)
miguelito=Node("mascota", name="Miguelito", edad=10)
mouse=Node("mascota", name="Mouse", edad=2)
hamtaro=Node("mascota", name="Hamtaro", edad=3)
martin=Node("mascota", name="Martin",edad=15)
laica=Node("mascota", name="Laica", edad=8)
guffy=Node("mascota", name="Guffy", edad=2)
blanca=Node("mascota", name="Blanca", edad=13)
silvestre=Node("mascota", name="Silvestre", edad=5)
piolin=Node("mascota", name="Piolin", edad=4)
basketball=Node("hobbie", name="Basketball")
futbol=Node("hobbie", name="Futbol")
natacion=Node("hobbie", name="Natacion")
voleyball=Node("hobbie", name="Voleyball")
tenis=Node("hobbie", name="Tenis")
lol=Node("hobbie", name="Lol")
fifa=Node("hobbie", name="Fifa")
pes=Node("hobbie", name="Pes")
bicicleta=Node("hobbie", name="Bicicleta")
ejercicio=Node("hobbie", name="Ejercicio")
netflix=Node("hobbie", name="Netflix")
facebook=Node("redsocial", name="Facebook")
twitter=Node("redsocial", name="Twitter")
instagram=Node("redsocial", name="Instagram")
fotolog=Node("redsocial", name="Fotolog")
perro=Node("nodo", name="Perro")
gato=Node("nodo", name="Gato")
hamster=Node("nodo", name="Hamster")
loro=Node("nodo", name="Loro")

# %%
graph.create(alejandra)
graph.create(claudia)
graph.create(macarena)
graph.create(boris)
graph.create(diego)
graph.create(mauricio)
graph.create(francisco)
graph.create(javier)
graph.create(jorge)
graph.create(patricia)
graph.create(andres)
graph.create(natalia)
graph.create(pamela)
graph.create(constanza)
graph.create(roberto)
graph.create(danae)
graph.create(tammy)
graph.create(linda)
graph.create(olivia)
graph.create(linda)
graph.create(andronico)
graph.create(kitty)
graph.create(garfield)
graph.create(tom)
graph.create(miguelito)
graph.create(mouse)
graph.create(martin)
graph.create(laica)
graph.create(guffy)
graph.create(silvestre)
graph.create(blanca)
graph.create(piolin)
graph.create(hamtaro)
graph.create(basketball)
graph.create(futbol)
graph.create(voleyball)
graph.create(natacion)
graph.create(tenis)
graph.create(lol)
graph.create(fifa)
graph.create(pes)
graph.create(bicicleta)
graph.create(ejercicio)
graph.create(netflix)
graph.create(facebook)
graph.create(twitter)
graph.create(instagram)
graph.create(fotolog)
graph.create(perro)
graph.create(hamster)
graph.create(loro)
graph.create(gato)

# %%
graph.create(Relationship(mauricio, "esfamiliade", javier))
graph.create(Relationship(mauricio, "esfamiliade", patricia))
graph.create(Relationship(mauricio, "esfamiliade", jorge))
graph.create(Relationship(mauricio, "usa", facebook))
graph.create(Relationship(mauricio, "usa", twitter))
graph.create(Relationship(mauricio, "usa", instagram))
graph.create(Relationship(mauricio, "hobbie", ejercicio))
graph.create(Relationship(mauricio, "hobbie", bicicleta))
graph.create(Relationship(javier, "usa", facebook))
graph.create(Relationship(javier, "usa", instagram))
graph.create(Relationship(patricia, "usa", facebook))
graph.create(Relationship(jorge, "usa", facebook))
graph.create(Relationship(javier, "hobbie", lol))
graph.create(Relationship(javier, "hobbie", fifa))
graph.create(Relationship(javier, "hobbie", basketball))
graph.create(Relationship(patricia, "hobbie", natacion))
graph.create(Relationship(patricia, "hobbie", netflix))
graph.create(Relationship(jorge, "hobbie", netflix))
graph.create(Relationship(jorge, "hobbie", tenis))
graph.create(Relationship(jorge, "hobbie", basketball))
graph.create(Relationship(mauricio, "sumascotaes", tammy))
graph.create(Relationship(mauricio, "sumascotaes", olivia))
graph.create(Relationship(mauricio, "sumascotaes", linda))
graph.create(Relationship(mauricio, "sumascotaes", maxima))
graph.create(Relationship(mauricio, "sumascotaes", pascuala))
graph.create(Relationship(javier, "sumascotaes", tammy))
graph.create(Relationship(javier, "sumascotaes", olivia))
graph.create(Relationship(javier, "sumascotaes", linda))
graph.create(Relationship(javier, "sumascotaes", maxima))
graph.create(Relationship(javier, "sumascotaes", pascuala))
graph.create(Relationship(jorge, "sumascotaes", tammy))
graph.create(Relationship(jorge, "sumascotaes", olivia))
graph.create(Relationship(jorge, "sumascotaes", linda))
graph.create(Relationship(jorge, "sumascotaes", maxima))
graph.create(Relationship(jorge, "sumascotaes", pascuala))
graph.create(Relationship(patricia, "sumascotaes", tammy))
graph.create(Relationship(patricia, "sumascotaes", olivia))
graph.create(Relationship(patricia, "sumascotaes", linda))
graph.create(Relationship(patricia, "sumascotaes", maxima))
graph.create(Relationship(patricia, "sumascotaes", pascuala))
graph.create(Relationship(andres, "esprimode", mauricio))
graph.create(Relationship(danae, "esprimode", mauricio))
graph.create(Relationship(natalia, "esprimode", mauricio))
graph.create(Relationship(andres, "esfamiliade", natalia))
graph.create(Relationship(andres, "esfamiliade", danae))
graph.create(Relationship(andres, "sumascotaes", garfield))
graph.create(Relationship(andres, "sumascotaes", martin))
graph.create(Relationship(andres, "sumascotaes", blanca))
graph.create(Relationship(danae, "sumascotaes", martin))
graph.create(Relationship(danae, "sumascotaes", blanca))
graph.create(Relationship(danae, "sumascotaes", garfield))
graph.create(Relationship(andres, "sumascotaes", guffy))
graph.create(Relationship(danae, "sumascotaes", garfield))
graph.create(Relationship(andres, "sumascotaes", guffy))
graph.create(Relationship(andres, "sumascotaes", miguelito))
graph.create(Relationship(danae, "sumascotaes", kitty))
graph.create(Relationship(andres, "sumascotaes", andronico))
graph.create(Relationship(andres, "hobbie", lol))
graph.create(Relationship(andres, "hobbie", fifa))
graph.create(Relationship(andres, "hobbie", pes))
graph.create(Relationship(andres, "hobbie", voleyball))
graph.create(Relationship(natalia, "hobbie", ejercicio))
graph.create(Relationship(natalia, "hobbie", netflix))
graph.create(Relationship(danae, "hobbie",tenis ))
graph.create(Relationship(andres, "usa", facebook))
graph.create(Relationship(natalia, "usa", facebook))
graph.create(Relationship(natalia, "usa", instagram))
graph.create(Relationship(mauricio, "esamigode", diego))
graph.create(Relationship(mauricio, "esamigode",boris ))
graph.create(Relationship(diego, "esprimode", constanza))
graph.create(Relationship(constanza, "sumascotaes", silvestre))
graph.create(Relationship(diego, "hobbie",futbol ))
graph.create(Relationship(diego, "hobbie",pes ))
graph.create(Relationship(constanza, "hobbie",bicicleta ))
graph.create(Relationship(diego, "usa", facebook))
graph.create(Relationship(constanza, "usa", fotolog))
graph.create(Relationship(constanza, "usa", facebook))
graph.create(Relationship(constanza, "esamigode", alejandra))
graph.create(Relationship(constanza, "esamigode", claudia))
graph.create(Relationship(constanza, "esamigode", macarena))
graph.create(Relationship(alejandra, "esfamiliade", claudia))
graph.create(Relationship(alejandra, "sumascotaes", tom))
graph.create(Relationship(alejandra, "sumascotaes", miguelito))
graph.create(Relationship(claudia, "sumascotaes", tom))
graph.create(Relationship(claudia, "sumascotaes", miguelito))
graph.create(Relationship(macarena, "usa", facebook))
graph.create(Relationship(claudia, "usa", facebook))
graph.create(Relationship(claudia, "usa", fotolog))
graph.create(Relationship(claudia, "hobbie", natacion))
graph.create(Relationship(claudia, "hobbie", basketball))
graph.create(Relationship(macarena, "hobbie", voleyball))
graph.create(Relationship(boris, "esamigode", pamela))
graph.create(Relationship(pamela, "sumascotaes", piolin))
graph.create(Relationship(pamela, "sumascotaes", laica))
graph.create(Relationship(andres, "esamigode", roberto))
graph.create(Relationship(andres, "esamigode", francisco))
graph.create(Relationship(roberto, "sumascotaes", tom))
graph.create(Relationship(roberto, "sumascotaes", mouse))
graph.create(Relationship(roberto, "sumascotaes", hamtaro))
graph.create(Relationship(roberto, "usa", twitter))
graph.create(Relationship(roberto, "hobbie", natacion))
graph.create(Relationship(roberto, "hobbie", netflix))
graph.create(Relationship(francisco, "usa", instagram))
graph.create(Relationship(pamela, "usa", twitter))
graph.create(Relationship(pamela, "usa", facebook))
graph.create(Relationship(pamela, "usa", instagram))
graph.create(Relationship(pamela, "usa", fotolog))
graph.create(Relationship(tammy, "esun", perro))
graph.create(Relationship(olivia, "esun", perro))
graph.create(Relationship(pascuala, "esun", perro))
graph.create(Relationship(maxima, "esun", perro))
graph.create(Relationship(linda, "esun", perro))
graph.create(Relationship(tammy, "esun", perro))
graph.create(Relationship(martin, "esun", perro))
graph.create(Relationship(laica, "esun", perro))
graph.create(Relationship(mouse, "esun", hamster))
graph.create(Relationship(hamtaro, "esun", hamster))
graph.create(Relationship(piolin, "esun", loro))
graph.create(Relationship(garfield, "esun", gato))
graph.create(Relationship(kitty, "esun", gato))
graph.create(Relationship(blanca, "esun", gato))
graph.create(Relationship(silvestre, "esun", gato))
graph.create(Relationship(guffy, "esun", gato))
graph.create(Relationship(tom, "esun", gato))
graph.create(Relationship(andronico, "esun", gato))
graph.create(Relationship(miguelito, "esun", gato))
